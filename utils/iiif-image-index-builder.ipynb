# %%
import requests

found_uris = list()
starting_collection = 'https://lbiiif.riksarkivet.se/collection/riksarkivet'
collections_needing_images = list()
image_index = list()

# %%
import json
def traverse(url):
    r = requests.get(url)
    print(url)

    found_uris.append(url)

    if r.status_code != 200:
        return

    try:
        data = r.json()
    except (JSONDecodeError, json.JSONDecodeError):
        print(r.text)

    for item in data['items']:

        if item['id'] in found_uris:
            continue

        if item['type'] == 'Collection':
            collections_needing_images.append(item['id'])
            traverse(item['id'])
        elif item['type'] == 'Manifest':
            image = get_image_from_manifest(item['id'])
            if image:
                image_index.append([item['id'], image])
                for collection in collections_needing_images:
                    image_index.append([collection, get_image_from_manifest(item['id'])])
            collections_needing_images.clear()


def get_image_from_manifest(manifest_url):
    manifest = requests.get(manifest_url).json()
    if len(manifest['items']) > 0:
        item = manifest['items'][round(len(manifest['items']) / 2) - 1]
        if item['type'] == 'Canvas':
            return item['id']
    return False

traverse(starting_collection)
# Out:
# https://lbiiif.riksarkivet.se/collection/riksarkivet
# https://lbiiif.riksarkivet.se/collection/amnesomraden
# https://lbiiif.riksarkivet.se/collection/bouppteckningar
# https://lbiiif.riksarkivet.se/collection/arkiv/EryBrktQbw38zq109POSD4
# https://lbiiif.riksarkivet.se/collection/domstolsarkiv
# https://lbiiif.riksarkivet.se/collection/domstolsarkiv/Blekinge län
# https://lbiiif.riksarkivet.se/collection/arkiv/HfxhKREDxa6556ypmSIxq5
# https://lbiiif.riksarkivet.se/collection/arkiv/feAwCAyVvgJO0RyFX9vAF8
# https://lbiiif.riksarkivet.se/collection/arkiv/oFwezCAasQBU3gyr5Q2EPE
# https://lbiiif.riksarkivet.se/collection/arkiv/2Mza5gXmJAHRVW1kDBWMx2
# https://lbiiif.riksarkivet.se/collection/arkiv/3lzr5hf8FgHOr9CivYcjY6
# https://lbiiif.riksarkivet.se/collection/arkiv/EchzY553UYTO0ZtuseBw01
# https://lbiiif.riksarkivet.se/collection/arkiv/TCEveWvCI4kjFCJPICtxa0
# https://lbiiif.riksarkivet.se/collection/arkiv/seutYtD7nq6cUfNirExCp2
# https://lbiiif.riksarkivet.se/collection/arkiv/kR4F1us4wqYzVcPetzOdoC
# https://lbiiif.riksarkivet.se/collection/arkiv/djiIocbWnaccvBtGe0pnF1
# https://lbiiif.riksarkivet.se/collection/arkiv/QvGy5Y5FXoDPizL7GStVlF
# https://lbiiif.riksarkivet.se/collection/arkiv/ChUjJs23baEEF7VNOPahJ2
# https://lbiiif.riksarkivet.se/collection/arkiv/xJu63E4nGq6rnTV0N239H2
# https://lbiiif.riksarkivet.se/collection/arkiv/3f6zydzH5IarYo5PqWc3y5
# https://lbiiif.riksarkivet.se/collection/arkiv/BHidtdIW4qELe7iVpN5Qo2
# https://lbiiif.riksarkivet.se/collection/arkiv/ftUztZhvEwN6gzy4I7FP1V
# https://lbiiif.riksarkivet.se/collection/arkiv/nsCHjheTGawE8aIsztfLo6
# https://lbiiif.riksarkivet.se/collection/arkiv/WPpHGvx5J4g66YlA2DeiC0
# https://lbiiif.riksarkivet.se/collection/arkiv/GU3BtHNVGKQfRw4Rz4e2b2
# https://lbiiif.riksarkivet.se/collection/domstolsarkiv/Dalarnas län
# https://lbiiif.riksarkivet.se/collection/arkiv/yrsZIcmaweZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv
JTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/wV0NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/wl0NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/xV0NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/yFWBn7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/ydWBn7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/yAarl7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/zFWBn7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/0l4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/yIarl7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/yYarl7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/yQarl7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/5F4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/7F4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/ygarl7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/Al4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/BF4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/DV4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/yoarl7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/El4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/EzYBn7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/Fl4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/Hl4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/ywarl7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/IzYBn7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/LF4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/WHJ3Diu644c7kcdbqFUNS0
# https://lbiiif.riksarkivet.se/collection/arkiv/Ay3IkjqmfYVE9gMzfHKoyH
# https://lbiiif.riksarkivet.se/collection/arkiv/5yOMjrnAPY5FOBoEH416W6
# https://lbiiif.riksarkivet.se/collection/arkiv/z2arl7kaQeZJTe018W43t3
# https://lbiiif.riksarkivet.se/collection/arkiv/MF4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/MV4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/OV4NYFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/0LDhUFT8rH6cxG02H087k3
# https://lbiiif.riksarkivet.se/collection/arkiv/nV4NYFT8rH6cxG02H087k3
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /usr/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /usr/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[72], line 41
#      38             return item['id']
#      39     return False
# ---> 41 traverse(starting_collection)
#
# Cell In[72], line 23, in traverse(url)
#      21 if item['type'] == 'Collection':
#      22     collections_needing_images.append(item['id'])
# ---> 23     traverse(item['id'])
#      24 elif item['type'] == 'Manifest':
#      25     image = get_image_from_manifest(item['id'])
#
# Cell In[72], line 23, in traverse(url)
#      21 if item['type'] == 'Collection':
#      22     collections_needing_images.append(item['id'])
# ---> 23     traverse(item['id'])
#      24 elif item['type'] == 'Manifest':
#      25     image = get_image_from_manifest(item['id'])
#
#     [... skipping similar frames: traverse at line 23 (3 times)]
#
# Cell In[72], line 23, in traverse(url)
#      21 if item['type'] == 'Collection':
#      22     collections_needing_images.append(item['id'])
# ---> 23     traverse(item['id'])
#      24 elif item['type'] == 'Manifest':
#      25     image = get_image_from_manifest(item['id'])
#
# Cell In[72], line 25, in traverse(url)
#      23     traverse(item['id'])
#      24 elif item['type'] == 'Manifest':
# ---> 25     image = get_image_from_manifest(item['id'])
#      26     if image:
#      27         image_index.append([item['id'], image])
#
# Cell In[72], line 34, in get_image_from_manifest(manifest_url)
#      33 def get_image_from_manifest(manifest_url):
# ---> 34     manifest = requests.get(manifest_url).json()
#      35     if len(manifest['items']) > 0:
#      36         item = manifest['items'][round(len(manifest['items']) / 2) - 1]
#
# File ~/.local/lib/python3.10/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import csv

# write image index to csv
with open('image_index.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    writer.writerows(image_index)

# %%
get_image_from_manifest('https://lbiiif.riksarkivet.se/arkis!L0000020/manifest')
# Out:
# 'https://lbiiif.riksarkivet.se/arkis!L0000020_00335/canvas'

# %%
len(image_index)
# Out:
# 1053

# %%
# write the index to a csv file
import csv
with open('image_index.csv', 'w') as f:
    writer = csv.writer(f)
    for uri in found_uris:
        writer.writerow([uri])
